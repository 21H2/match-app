# %%
<VSCode.Cell language="markdown">
## Pegada → Bunk rename playbook
This notebook runs controlled search-and-replace steps (skipping `.git` and `node_modules`) to rename Pegada to Bunk across the workspace.
</VSCode.Cell>
<VSCode.Cell language="python">
from pathlib import Path
import os
import subprocess
import json

workspace_root = Path("/workspaces/match-app")
assert (workspace_root / ".git").exists(), "Workspace missing .git; aborting for safety"
print(f"workspace_root={workspace_root}")
</VSCode.Cell>
markdown
python
/workspaces/match-app
.git
Workspace missing .git; aborting for safety
workspace_root={workspace_root}
markdown
python
./.git/*
./node_modules/*
20
pegada|Pegada|@pegada|pegada\.app
# !.git/*
# !node_modules/*
40
markdown
python
$WORKSPACE
./.git/*
./node_modules/*
$file
$file
bash
-lc
markdown
python
package.json
apps/mobile/package.json
apps/nextjs/package.json
apps/queue/package.json
packages/api/package.json
packages/database/package.json
packages/shared/package.json
tools/eslint/package.json
tools/prettier/package.json
tools/tsconfig/package.json
python
